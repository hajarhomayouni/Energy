# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from matplotlib.pyplot import locator_params
from numpy import genfromtxt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import normalize
from operator import add
import tensorflow as tf
#rom keras.backend import tensorflow_backend as K
import statsmodels
import statistics
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
def temporalize(arr,win_size,step_size,features,add_index=0):
  """
  arr: any 2D array whose columns are distinct variables and 
    rows are data records at some timestamp t
  win_size: size of data window (given in data points)
  step_size: size of window step (given in data point)
  
  Note that step_size is related to window overlap (overlap = win_size - step_size), in 
  case you think in overlaps."""
  #
  dataFrameTimeseries=pd.DataFrame()
  #
  w_list = list()
  n_records = arr.shape[0]
  remainder = (n_records - win_size) % step_size 
  num_windows = 1 + int((n_records - win_size - remainder) / step_size)
  for k in range(num_windows):
    w_list.append(arr[k*step_size:win_size-1+k*step_size+1])
    #
    #convert the matrix to data frame
    dataFrameTemp=pd.DataFrame(data=arr[k*step_size:win_size-1+k*step_size+1], columns=features)
    dataFrameTemp["timeseriesId"]=k+add_index
    dataFrameTimeseries=pd.concat([dataFrameTimeseries,dataFrameTemp])
    #
  return np.array(w_list),dataFrameTimeseries

# %%
def is_number(s):
        try:
            float(s)
            return True
        except ValueError:
            pass
        
        try:
            import unicodedata
            unicodedata.numeric(s)
            return True
        except (TypeError, ValueError):
            pass
        return False

# %%
win_size=10
overlap=win_size-1

# %%
dataset = pd.read_csv('datasets/test1.csv', engine='python')
#preprocess data
dataset=dataset.fillna(-1)
for column in dataset.columns:
    if is_number(dataset.iloc[1][column]) and column!="id":
        min_max=MinMaxScaler(feature_range=(0, 1))
        dataset[[column]]=min_max.fit_transform(dataset[[column]])

n_features=len(dataset.columns.values)
X,dataFrameTimeseries=temporalize(dataset.to_numpy(),win_size,win_size-overlap,dataset.columns.values)

# %%
#LSTM-Autoencoder
model = Sequential()
model.add(LSTM(20,activation='tanh', input_shape=(win_size,n_features-2), return_sequences=False))
#model.add(LSTM(3, activation='relu', return_sequences=False))
model.add(RepeatVector(win_size))
#model.add(LSTM(3, activation='relu', return_sequences=True))
model.add(LSTM(20, activation='tanh', return_sequences=True))
model.add(TimeDistributed(Dense(n_features-2)))
model.compile(optimizer='adam', loss="mse")
model.summary()
# fit model
Xtrain=np.asarray(np.delete(X,[0,1],axis=2)).astype(np.float32)
model.fit(Xtrain, Xtrain, epochs=100, verbose=1)

yhat = model.predict(Xtrain, verbose=1)

#this structure is because overlap is win_size-1. Uncomment the commented lines for overlap=0
#h_axis=np.array(dataFrameTimeseries["time"])
h_axis=np.array(X)[:,0,1].flatten()
#v1_axis=np.array(dataFrameTimeseries["residential-dailyDelivered"])
v1_axis=np.array(X)[:,0,3].flatten()
#v2_axis=np.array(yhat)[:,:,1].flatten()
v2_axis=np.array(yhat)[:,0,1].flatten()
# Out:
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_74 (LSTM)               (None, 20)                1840
# _________________________________________________________________
# repeat_vector_26 (RepeatVect (None, 10, 20)            0
# _________________________________________________________________
# lstm_75 (LSTM)               (None, 10, 20)            3280
# _________________________________________________________________
# time_distributed_26 (TimeDis (None, 10, 2)             42
# =================================================================
# Total params: 5,162
# Trainable params: 5,162
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 18/18 [==============================] - 0s 19ms/step - loss: 0.2080
# Epoch 2/100
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0725
# Epoch 3/100
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0536
# Epoch 4/100
# 18/18 [==============================] - 0s 19ms/step - loss: 0.0418
# Epoch 5/100
# 18/18 [==============================] - 0s 17ms/step - loss: 0.0305
# Epoch 6/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0218
# Epoch 7/100
# 18/18 [==============================] - 0s 16ms/step - loss: 0.0163
# Epoch 8/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0134
# Epoch 9/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0116
# Epoch 10/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0103
# Epoch 11/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0096
# Epoch 12/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0087
# Epoch 13/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0081
# Epoch 14/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 15/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0075
# Epoch 16/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0074
# Epoch 17/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0072
# Epoch 18/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0071
# Epoch 19/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0070
# Epoch 20/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 21/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 22/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0069
# Epoch 23/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0069
# Epoch 24/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0068
# Epoch 25/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0068
# Epoch 26/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 27/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 28/100
# 18/18 [==============================] - 0s 15ms/step - loss: 0.0067
# Epoch 29/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 30/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 31/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0066
# Epoch 32/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0066
# Epoch 33/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0066
# Epoch 34/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0066
# Epoch 35/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0066
# Epoch 36/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0066
# Epoch 37/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0066
# Epoch 38/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0066
# Epoch 39/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 40/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 41/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 42/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0065
# Epoch 43/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0065
# Epoch 44/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0066
# Epoch 45/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0065
# Epoch 46/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 47/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 48/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 49/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0065
# Epoch 50/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 51/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 52/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 53/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 54/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 55/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0064
# Epoch 56/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 57/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0063
# Epoch 58/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 59/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0063
# Epoch 60/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0063
# Epoch 61/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0062
# Epoch 62/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 63/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 64/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0062
# Epoch 65/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0062
# Epoch 66/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 67/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0061
# Epoch 68/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0061
# Epoch 69/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 70/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 71/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0060
# Epoch 72/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 73/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 74/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0058
# Epoch 75/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0059
# Epoch 76/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 77/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 78/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 79/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 80/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0055
# Epoch 81/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0054
# Epoch 82/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0054
# Epoch 83/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0053
# Epoch 84/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0052
# Epoch 85/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0053
# Epoch 86/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0052
# Epoch 87/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0053
# Epoch 88/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0052
# Epoch 89/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0051
# Epoch 90/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 91/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0051
# Epoch 92/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 93/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0050
# Epoch 94/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.0050
# Epoch 95/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 96/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0051
# Epoch 97/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0049
# Epoch 98/100
# 18/18 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 99/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0048
# Epoch 100/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.0047
# 18/18 [==============================] - 0s 4ms/step

# %%
#Original LSTM
X=X[0:-1,:]
#only use delivered as network output
Y=dataset.to_numpy()[win_size:,3].astype(np.float32)
#X = X.reshape(X.shape[0], win_size, n_features)
#Y = Y.reshape(Y.shape[0], win_size, n_features)
model = Sequential()
model.add(LSTM(20, activation=('tanh'), dropout=0.2, recurrent_dropout=0.2, stateful = False, input_shape = (win_size,n_features-2)))
model.add(Dense(1))
model.compile(loss=keras.losses.mean_squared_error, optimizer='rmsprop')
model.summary()

#Exclude id and time
X=np.asarray(np.delete(X,[0,1],axis=2)).astype(np.float32)

model.fit(X, Y,epochs=100,verbose=1)
yhat=model.predict(X)
# Out:
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_77 (LSTM)               (None, 20)                1840
# _________________________________________________________________
# dense_43 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 1,861
# Trainable params: 1,861
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.7735
# Epoch 2/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.2216
# Epoch 3/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0357
# Epoch 4/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0185
# Epoch 5/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0187
# Epoch 6/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0176
# Epoch 7/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0169
# Epoch 8/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0161
# Epoch 9/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0144
# Epoch 10/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0149
# Epoch 11/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0167
# Epoch 12/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0152
# Epoch 13/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0150
# Epoch 14/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0147
# Epoch 15/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0146
# Epoch 16/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0129
# Epoch 17/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0140
# Epoch 18/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0138
# Epoch 19/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0139
# Epoch 20/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0131
# Epoch 21/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0130
# Epoch 22/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0138
# Epoch 23/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0128
# Epoch 24/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0126
# Epoch 25/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0126
# Epoch 26/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0133
# Epoch 27/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0131
# Epoch 28/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0121
# Epoch 29/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0124
# Epoch 30/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0122
# Epoch 31/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0129
# Epoch 32/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0123
# Epoch 33/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0130
# Epoch 34/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0125
# Epoch 35/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0125
# Epoch 36/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0134
# Epoch 37/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0123
# Epoch 38/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0128
# Epoch 39/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0117
# Epoch 40/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0117
# Epoch 41/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0113
# Epoch 42/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0119
# Epoch 43/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0119
# Epoch 44/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0117
# Epoch 45/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0124
# Epoch 46/100
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0113
# Epoch 47/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0120
# Epoch 48/100
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0115
# Epoch 49/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0124
# Epoch 50/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0115
# Epoch 51/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0118
# Epoch 52/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0110
# Epoch 53/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 54/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0123
# Epoch 55/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0107
# Epoch 56/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0108
# Epoch 57/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 58/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 59/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 60/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 61/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 62/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 63/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0112
# Epoch 64/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 65/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0115
# Epoch 66/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0108
# Epoch 67/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0110
# Epoch 68/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 69/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0114
# Epoch 70/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 71/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0107
# Epoch 72/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0110
# Epoch 73/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0103
# Epoch 74/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 75/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0108
# Epoch 76/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 77/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0101
# Epoch 78/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0121
# Epoch 79/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0111
# Epoch 80/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0099
# Epoch 81/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0115
# Epoch 82/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 83/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 84/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 85/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0104
# Epoch 86/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0101
# Epoch 87/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0102
# Epoch 88/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0105
# Epoch 89/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0100
# Epoch 90/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0106
# Epoch 91/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0100
# Epoch 92/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0101
# Epoch 93/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0103
# Epoch 94/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0106
# Epoch 95/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0098
# Epoch 96/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0101
# Epoch 97/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0101
# Epoch 98/100
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0110
# Epoch 99/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0109
# Epoch 100/100
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0101

# %%
h_axis=dataset["time"]
v1_axis=dataset["residential-dailyDelivered"]
v2_axis=yhat.flatten()
temp=np.zeros(win_size)
v2_axis=np.concatenate([temp,v2_axis])

# %%
plt.rcParams.update({'font.size': 15})
plt.tight_layout()
plt.figure(figsize=(30,3))
plt.plot(h_axis, v1_axis, color="blue",marker="o", label="actual")
plt.plot(h_axis,v2_axis, color="red",marker="o",label="predicted")
plt.xticks(rotation=90)
plt.title("Title")
plt.show()

# %%
#TODO:
#1. Use pre covid data to train and post covid data to test your model. use green and red colors for predict(train) and predic(Test). Does it make sence??
#2. Use less tiks for X axis
#3. Put plot in a function and use it for both models
