# %% [markdown]
# # The effect of COVID-19 on deliveredKwh
# We designed three machine learning-based model (LSTM-based) that to predict the value of "dailyDeleivered".
#
# We monitored the prediction error of the pre and post COVID data to observe the effect of COVID-19 on the prediction error.
# We also observed the sign of the prediction error to see whether the predicted dailyDelivered values are greater or less than the actula values.
# The following code and results are for a dataset that contains data of residential premises.
#
# The prediction error for post-covid data is greater than the one for pre-covid data.

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from matplotlib.pyplot import locator_params
from numpy import genfromtxt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import normalize
from operator import add
import tensorflow as tf
#rom keras.backend import tensorflow_backend as K
import statsmodels
import statistics
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
def temporalize(arr,win_size,step_size,features,add_index=0):
  """
  arr: any 2D array whose columns are distinct variables and 
    rows are data records at some timestamp t
  win_size: size of data window (given in data points)
  step_size: size of window step (given in data point)
  
  Note that step_size is related to window overlap (overlap = win_size - step_size), in 
  case you think in overlaps."""
  #
  dataFrameTimeseries=pd.DataFrame()
  #
  w_list = list()
  n_records = arr.shape[0]
  remainder = (n_records - win_size) % step_size 
  num_windows = 1 + int((n_records - win_size - remainder) / step_size)
  for k in range(num_windows):
    w_list.append(arr[k*step_size:win_size-1+k*step_size+1])
    #
    #convert the matrix to data frame
    dataFrameTemp=pd.DataFrame(data=arr[k*step_size:win_size-1+k*step_size+1], columns=features)
    dataFrameTemp["timeseriesId"]=k+add_index
    dataFrameTimeseries=pd.concat([dataFrameTimeseries,dataFrameTemp])
    #
  return np.array(w_list),dataFrameTimeseries

# %%
def is_number(s):
        try:
            float(s)
            return True
        except ValueError:
            pass
        
        try:
            import unicodedata
            unicodedata.numeric(s)
            return True
        except (TypeError, ValueError):
            pass
        return False

# %%
def plot_(h_axis,v1_axis,v2_axis, title="Daily Delivered (kWh)"):
    plt.rcParams.update({'font.size': 15})
    plt.tight_layout()
    plt.figure(figsize=(30,3))
    plt.plot(h_axis, v1_axis, color="blue",marker="o", label="actual")
    plt.plot(h_axis,v2_axis, color="red",marker="o",label="predicted")
    plt.xticks(h_axis[0::31],rotation=90)
    plt.title(title)
    plt.show()

# %%
# split into train and test sets
def split_(dataset, train_size=0.67, dimension=2):
    train_size = int(len(dataset) * train_size)
    test_size = len(dataset) - train_size
    train=[]
    test=[]
    if dimension==1:
        train, test = dataset[0:train_size], dataset[train_size:len(dataset)]
    else:
        train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    return train,test

# %%
#Original LSTM
def lstm_(X,Y,n_features,excludedIndexes=[0,1],trainig_percentage=0.76):
    model = Sequential()
    model.add(LSTM(100, activation=('tanh'), dropout=0.2, recurrent_dropout=0.2, stateful = False, input_shape = (win_size,n_features-len(excludedIndexes))))
    model.add(Dense(1))
    model.compile(loss=keras.losses.mean_squared_error, optimizer='rmsprop')
    model.summary()

    #Exclude indexes for analysis in training
    X_preprocessed=np.asarray(np.delete(X,excludedIndexes,axis=2)).astype(np.float32)
    #train on precovid data and test on all dataset
    Xtrain,Xtest=split_(X_preprocessed,trainig_percentage)
    Ytrain,Ytest=split_(Y,trainig_percentage,1)

    model.fit(Xtrain, Ytrain,epochs=100,verbose=1)
    #prediction error on pre-covid data (training data)
    yhat1 = model.predict(Xtrain, verbose=0)
    prediction_error1=np.square(Ytrain-yhat1).mean(axis=None).ravel()
    print("prediction error on pre-covid data")
    print("**********************************")
    print(prediction_error1)

    #prediction error on post-covid data (testing data)
    yhat2 = model.predict(Xtest, verbose=0)
    prediction_error2=np.square(Ytest-yhat2).mean(axis=None).ravel()
    print("prediction error on post-covid data")
    print("**********************************")
    print(prediction_error2)

    print("Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted")
    print("**********************************")
    print((Ytest-yhat2).mean(axis=None))

    #predict the entire data
    yhat=model.predict(X_preprocessed)

    h_axis=dataset["time"]
    v1_axis=dataset["dailyDelivered"]
    v2_axis=yhat.flatten()
    temp=np.zeros(win_size)
    v2_axis=np.concatenate([temp,v2_axis])
    plot_(h_axis,v1_axis,v2_axis)

# %%
def lstmAutoencoer(X,n_features,dailyDeliveredIndex=3,trainig_percentage=0.76):
    #LSTM-Autoencoder
    model = Sequential()
    model.add(LSTM(20,activation='tanh', input_shape=(win_size,n_features-2), return_sequences=False))
    model.add(RepeatVector(win_size))
    model.add(LSTM(20, activation='tanh', return_sequences=True))
    #2: excludes id and time from analysis
    model.add(TimeDistributed(Dense(n_features-2)))
    model.compile(optimizer='adam', loss="mse")
    model.summary()

    #remove id and time for trainig
    X_preprocessed=np.asarray(np.delete(X,[0,1],axis=2)).astype(np.float32)
    #train on precovid data and test on all dataset
    train,test=split_(X_preprocessed,trainig_percentage)

    model.fit(train, train, epochs=500, verbose=1)
    #prediction error on pre-covid data (training data)
    yhat1 = model.predict(train, verbose=0)
    prediction_error1=np.square(train-yhat1).mean(axis=None).ravel()
    print("prediction error on pre-covid data")
    print("**********************************")
    print(prediction_error1)

    #prediction error on post-covid data (testing data)
    yhat2 = model.predict(test, verbose=0)
    prediction_error2=np.square(test-yhat2).mean(axis=None).ravel()
    print("prediction error on post-covid data")
    print("**********************************")
    print(prediction_error2)

    print("Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted")
    print("**********************************")
    print((test-yhat2).mean(axis=None))

    #predict the entire data
    yhat = model.predict(X_preprocessed, verbose=1)
    #this structure is because overlap is win_size-1. Uncomment the commented lines for overlap=0
    #h_axis=np.array(dataFrameTimeseries["time"])
    h_axis=np.array(X)[:,0,1].flatten()
    #v1_axis=np.array(dataFrameTimeseries["residential-dailyDelivered"])
    v1_axis=np.array(X)[:,0,dailyDeliveredIndex].flatten()
    #v2_axis=np.array(yhat)[:,:,1].flatten()
    v2_axis=np.array(yhat)[:,0,1].flatten()
    plot_(h_axis,v1_axis,v2_axis)

# %%
#set window sizes and their overlap
win_size=10
overlap=win_size-1

#read data
dataset = pd.read_csv('datasets/pow_temp_isweekday.csv', engine='python')

#preprocess data
dataset=dataset.fillna(-1)
for column in dataset.columns:
    if is_number(dataset.iloc[1][column]) and column!="id":
        min_max=MinMaxScaler(feature_range=(0, 1))
        dataset[[column]]=min_max.fit_transform(dataset[[column]])

#set variables based on the data attributes
n_features=len(dataset.columns.values)
dailyDeliveredIndex=np.where(dataset.columns.values=="dailyDelivered")
dailyDeliveredIndex=dailyDeliveredIndex[0][0]
X,dataFrameTimeseries=temporalize(dataset.to_numpy(),win_size,win_size-overlap,dataset.columns.values)

# %%
#model1:
print("**********Model1: Original LSTM*******************************")
#remove id (index=0), time (index=1), and previous value of dailyDelivered for trainig
excludedIndexes=[0,1,dailyDeliveredIndex]
lstm_(X[0:-1,:],dataset.to_numpy()[win_size:,dailyDeliveredIndex].astype(np.float32),n_features,excludedIndexes,trainig_percentage=0.76)

#model2:
print("**********Model2: Original LSTM*******************************")
#remove id and time for trainig
excludedIndexes=[0,1]
lstm_(X[0:-1,:],dataset.to_numpy()[win_size:,dailyDeliveredIndex].astype(np.float32),n_features,excludedIndexes,trainig_percentage=0.76)

#model3:
print("**********Model3: LSTM-Autoencoder*******************************")
lstmAutoencoer(X,n_features,dailyDeliveredIndex,trainig_percentage=0.76)
# Out:
# **********Model1: Original LSTM*******************************
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               41200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 41,301
# Trainable params: 41,301
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0954
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0287
# Epoch 3/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0279
# Epoch 4/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0221
# Epoch 5/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0189
# Epoch 6/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0201
# Epoch 7/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0191
# Epoch 8/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0163
# Epoch 9/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0195
# Epoch 10/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0182
# Epoch 11/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0174
# Epoch 12/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0170
# Epoch 13/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0155
# Epoch 14/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0152
# Epoch 15/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0158
# Epoch 16/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0145
# Epoch 17/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0162
# Epoch 18/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0143
# Epoch 19/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0165
# Epoch 20/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0142
# Epoch 21/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0139
# Epoch 22/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0144
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0135
# Epoch 24/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0126
# Epoch 25/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0120
# Epoch 26/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0132
# Epoch 27/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0138
# Epoch 28/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0119
# Epoch 29/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0148
# Epoch 30/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# Epoch 31/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0140
# Epoch 32/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0134
# Epoch 33/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0137
# Epoch 34/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0125
# Epoch 35/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0119
# Epoch 36/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0122
# Epoch 37/100
# 13/13 [==============================] - ETA: 0s - loss: 0.011 - 0s 14ms/step - loss: 0.0119
# Epoch 38/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0131
# Epoch 39/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0123
# Epoch 40/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0135
# Epoch 41/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0115
# Epoch 42/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0117
# Epoch 43/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0125
# Epoch 44/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 45/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0118
# Epoch 46/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0120
# Epoch 47/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0107
# Epoch 48/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0113
# Epoch 49/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0114
# Epoch 50/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 51/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0111
# Epoch 52/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0108
# Epoch 53/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0128
# Epoch 54/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0116
# Epoch 55/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0121
# Epoch 56/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0104
# Epoch 57/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0118
# Epoch 58/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0096
# Epoch 59/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0121
# Epoch 60/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 61/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0105
# Epoch 62/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0116
# Epoch 63/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# Epoch 64/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0111
# Epoch 65/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0107
# Epoch 66/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0118
# Epoch 67/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 68/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0102
# Epoch 69/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0113
# Epoch 70/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0111
# Epoch 71/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0111
# Epoch 72/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0100
# Epoch 73/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0102
# Epoch 74/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 76/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0110
# Epoch 77/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0092
# Epoch 78/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0107
# Epoch 79/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0103
# Epoch 80/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# Epoch 81/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0116
# Epoch 82/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0095
# Epoch 83/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0113
# Epoch 84/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 85/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104
# Epoch 86/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097
# Epoch 87/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 88/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104
# Epoch 89/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0096
# Epoch 90/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104
# Epoch 91/100
# 13/13 [==============================] - ETA: 0s - loss: 0.010 - 0s 14ms/step - loss: 0.0101
# Epoch 92/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0100
# Epoch 93/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0095
# Epoch 94/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0100
# Epoch 95/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0107
# Epoch 96/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0098
# Epoch 97/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 99/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# Epoch 100/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0093
# prediction error on pre-covid data
# **********************************
# [0.01624506]
# prediction error on post-covid data
# **********************************
# [0.0349623]
# Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted
# **********************************
# -0.054496083
# **********Model2: Original LSTM*******************************
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               41600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 41,701
# Trainable params: 41,701
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0527
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0154
# Epoch 3/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0149
# Epoch 4/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0158
# Epoch 5/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0158
# Epoch 6/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0132
# Epoch 7/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0148
# Epoch 8/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0114
# Epoch 9/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 10/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0132
# Epoch 11/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0110
# Epoch 12/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0131
# Epoch 13/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 14/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 15/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0118
# Epoch 16/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0108
# Epoch 17/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 18/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0109
# Epoch 19/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0110
# Epoch 20/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 21/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 22/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0104
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0102
# Epoch 24/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# Epoch 25/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0094
# Epoch 26/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0096
# Epoch 27/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 28/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 29/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0102
# Epoch 30/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0113
# Epoch 31/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0088
# Epoch 32/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0096
# Epoch 33/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0084
# Epoch 34/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0091
# Epoch 35/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0096
# Epoch 36/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0093
# Epoch 37/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0102
# Epoch 38/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0091
# Epoch 39/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0086
# Epoch 40/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0091
# Epoch 41/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0089
# Epoch 42/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0086
# Epoch 43/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 44/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0093
# Epoch 45/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0089
# Epoch 46/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0085
# Epoch 47/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0094
# Epoch 48/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 49/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0087
# Epoch 50/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 51/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0091
# Epoch 52/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0093
# Epoch 53/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0081
# Epoch 54/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0089
# Epoch 55/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 56/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 57/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 58/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0093
# Epoch 59/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0080
# Epoch 60/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 61/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0089
# Epoch 62/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0086
# Epoch 63/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 64/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0080
# Epoch 65/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0085
# Epoch 66/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0082
# Epoch 67/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0075
# Epoch 68/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 69/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0084
# Epoch 70/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0076
# Epoch 71/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 72/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0075
# Epoch 73/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073
# Epoch 74/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0085
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0075
# Epoch 76/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078
# Epoch 77/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0075
# Epoch 78/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078
# Epoch 79/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0081
# Epoch 80/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0074
# Epoch 81/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082
# Epoch 82/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0079
# Epoch 83/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0071
# Epoch 84/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073
# Epoch 85/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0071
# Epoch 86/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0072
# Epoch 87/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 88/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0075
# Epoch 89/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 90/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0071
# Epoch 91/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078
# Epoch 92/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0066
# Epoch 93/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078
# Epoch 94/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0069
# Epoch 95/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0089
# Epoch 96/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0070
# Epoch 97/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 99/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0080
# Epoch 100/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0076
# prediction error on pre-covid data
# **********************************
# [0.01820944]
# prediction error on post-covid data
# **********************************
# [0.03484944]
# Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted
# **********************************
# -0.031585597
# **********Model3: LSTM-Autoencoder*******************************
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 20)                1920
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 10, 20)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 20)            3280
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 3)             63
# =================================================================
# Total params: 5,263
# Trainable params: 5,263
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.3508
# Epoch 2/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1553
# Epoch 3/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1134
# Epoch 4/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1039
# Epoch 5/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0983
# Epoch 6/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0938
# Epoch 7/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0892
# Epoch 8/500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0848
# Epoch 9/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0815
# Epoch 10/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0795
# Epoch 11/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0779
# Epoch 12/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0768
# Epoch 13/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0759
# Epoch 14/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0752
# Epoch 15/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0746
# Epoch 16/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0740
# Epoch 17/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0734
# Epoch 18/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0730
# Epoch 19/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0726
# Epoch 20/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0722
# Epoch 21/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0719
# Epoch 22/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0716
# Epoch 23/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0714
# Epoch 24/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0712
# Epoch 25/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0710
# Epoch 26/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0709
# Epoch 27/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0707
# Epoch 28/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0706
# Epoch 29/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0705
# Epoch 30/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0705
# Epoch 31/500
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0704
# Epoch 32/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0703
# Epoch 33/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0702
# Epoch 34/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0702
# Epoch 35/500
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0701
# Epoch 36/500
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0701
# Epoch 37/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0700
# Epoch 38/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0700
# Epoch 39/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0699
# Epoch 40/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0699
# Epoch 41/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0698
# Epoch 42/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0697
# Epoch 43/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0697
# Epoch 44/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0696
# Epoch 45/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0695
# Epoch 46/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0695
# Epoch 47/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0694
# Epoch 48/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0693
# Epoch 49/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0692
# Epoch 50/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0690
# Epoch 51/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0689
# Epoch 52/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0687
# Epoch 53/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0684
# Epoch 54/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0680
# Epoch 55/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0675
# Epoch 56/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0667
# Epoch 57/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0658
# Epoch 58/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0649
# Epoch 59/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0636
# Epoch 60/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0623
# Epoch 61/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0611
# Epoch 62/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0597
# Epoch 63/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0577
# Epoch 64/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0560
# Epoch 65/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0538
# Epoch 66/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0513
# Epoch 67/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0497
# Epoch 68/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0469
# Epoch 69/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0445
# Epoch 70/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0432
# Epoch 71/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0427
# Epoch 72/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0400
# Epoch 73/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0380
# Epoch 74/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0358
# Epoch 75/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0342
# Epoch 76/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0330
# Epoch 77/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0312
# Epoch 78/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0303
# Epoch 79/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0291
# Epoch 80/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0280
# Epoch 81/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0268
# Epoch 82/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0259
# Epoch 83/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0255
# Epoch 84/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0246
# Epoch 85/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0238
# Epoch 86/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0230
# Epoch 87/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0224
# Epoch 88/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0220
# Epoch 89/500
# 13/13 [==============================] - ETA: 0s - loss: 0.021 - 0s 14ms/step - loss: 0.0213
# Epoch 90/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0210
# Epoch 91/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0202
# Epoch 92/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0197
# Epoch 93/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0191
# Epoch 94/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0190
# Epoch 95/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0182
# Epoch 96/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0178
# Epoch 97/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0173
# Epoch 98/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0168
# Epoch 99/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0163
# Epoch 100/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0157
# Epoch 101/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0153
# Epoch 102/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0150
# Epoch 103/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0146
# Epoch 104/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0140
# Epoch 105/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0136
# Epoch 106/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0134
# Epoch 107/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0129
# Epoch 108/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0125
# Epoch 109/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0123
# Epoch 110/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0119
# Epoch 111/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0117
# Epoch 112/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0113
# Epoch 113/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0110
# Epoch 114/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 115/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0107
# Epoch 116/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0102
# Epoch 117/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0100
# Epoch 118/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 119/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0097
# Epoch 120/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0095
# Epoch 121/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0094
# Epoch 122/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0092
# Epoch 123/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0091
# Epoch 124/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 125/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0087
# Epoch 126/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0087
# Epoch 127/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 128/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082
# Epoch 129/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0081
# Epoch 130/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0079
# Epoch 131/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 132/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0079
# Epoch 133/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 134/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0074
# Epoch 135/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0074
# Epoch 136/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073
# Epoch 137/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0071
# Epoch 138/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0071
# Epoch 139/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0071
# Epoch 140/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0072
# Epoch 141/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0071
# Epoch 142/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0069
# Epoch 143/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 144/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 145/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0065
# Epoch 146/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0064
# Epoch 147/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0063
# Epoch 148/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0062
# Epoch 149/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0062
# Epoch 150/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0062
# Epoch 151/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0061
# Epoch 152/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0060
# Epoch 153/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 154/500
# 13/13 [==============================] - ETA: 0s - loss: 0.005 - 0s 14ms/step - loss: 0.0059
# Epoch 155/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0058
# Epoch 156/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0058
# Epoch 157/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0057
# Epoch 158/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0057
# Epoch 159/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0059
# Epoch 160/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0058
# Epoch 161/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0057
# Epoch 162/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0056
# Epoch 163/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0055
# Epoch 164/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0055
# Epoch 165/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0055
# Epoch 166/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0055
# Epoch 167/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0054
# Epoch 168/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0054
# Epoch 169/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0054
# Epoch 170/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0053
# Epoch 171/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0052
# Epoch 172/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0052
# Epoch 173/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0051
# Epoch 174/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0051
# Epoch 175/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0051
# Epoch 176/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0051
# Epoch 177/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0054
# Epoch 178/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0056
# Epoch 179/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0053
# Epoch 180/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0050
# Epoch 181/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0050
# Epoch 182/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0049
# Epoch 183/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0049
# Epoch 184/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0048
# Epoch 185/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0048
# Epoch 186/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 187/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 188/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 189/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 190/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 191/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 192/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0046
# Epoch 193/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0047
# Epoch 194/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0047
# Epoch 195/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0046
# Epoch 196/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0046
# Epoch 197/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0046
# Epoch 198/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 199/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 200/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0045
# Epoch 201/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 202/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0045
# Epoch 203/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 204/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 205/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0044
# Epoch 206/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0044
# Epoch 207/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0045
# Epoch 208/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 209/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0044
# Epoch 210/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0044
# Epoch 211/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 212/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0044
# Epoch 213/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 214/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 215/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 216/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 217/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 218/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 219/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 220/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0044
# Epoch 221/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0045
# Epoch 222/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0045
# Epoch 223/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 224/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0044
# Epoch 225/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0043
# Epoch 226/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0043
# Epoch 227/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0042
# Epoch 228/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0042
# Epoch 229/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0042
# Epoch 230/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0041
# Epoch 231/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 232/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0041
# Epoch 233/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 234/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0041
# Epoch 235/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 236/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 237/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 238/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 239/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0041
# Epoch 240/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0040
# Epoch 241/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 242/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 243/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 244/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 245/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 246/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 247/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 248/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0039
# Epoch 249/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 250/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0039
# Epoch 251/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 252/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 253/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 254/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 255/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0039
# Epoch 256/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0038
# Epoch 257/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0039
# Epoch 258/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0040
# Epoch 259/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0039
# Epoch 260/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 261/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 262/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 263/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 264/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 265/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 266/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 267/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 268/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 269/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 270/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 271/500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0037
# Epoch 272/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0037
# Epoch 273/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0037
# Epoch 274/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0038
# Epoch 275/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0037
# Epoch 276/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 277/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0037
# Epoch 278/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 279/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0037
# Epoch 280/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0037
# Epoch 281/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 282/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 283/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 284/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 285/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 286/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 287/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 288/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 289/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 290/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0037
# Epoch 291/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 292/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0035
# Epoch 293/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0035
# Epoch 294/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 295/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0035
# Epoch 296/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 297/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 298/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 299/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 300/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 301/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0035
# Epoch 302/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0035
# Epoch 303/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0036
# Epoch 304/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0036
# Epoch 305/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 306/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 307/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 308/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 309/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 310/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 311/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 312/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 313/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 314/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 315/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 316/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 317/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 318/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 319/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 320/500
# 13/13 [==============================] - ETA: 0s - loss: 0.003 - 0s 14ms/step - loss: 0.0033
# Epoch 321/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 322/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 323/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0033
# Epoch 324/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 325/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 326/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 327/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 328/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0033
# Epoch 329/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 330/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 331/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0033
# Epoch 332/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0034
# Epoch 333/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 334/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0033
# Epoch 335/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 336/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 337/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 338/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 339/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 340/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 341/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 342/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 343/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 344/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 345/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0033
# Epoch 346/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 347/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 348/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0033
# Epoch 349/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0034
# Epoch 350/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 351/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0032
# Epoch 352/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 353/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 354/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0032
# Epoch 355/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 356/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 357/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 358/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 359/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 360/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 361/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 362/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 363/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 364/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0031
# Epoch 365/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 366/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 367/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 368/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 369/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 370/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 371/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 372/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0031
# Epoch 373/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 374/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 375/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 376/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 377/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 378/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 379/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 380/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 381/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 382/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 383/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 384/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 385/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 386/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 387/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 388/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 389/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 390/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0030
# Epoch 391/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 392/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 393/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 394/500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0029
# Epoch 395/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 396/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 397/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 398/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 399/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 400/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 401/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 402/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 403/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 404/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 405/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 406/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 407/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0029
# Epoch 408/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 409/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 410/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 411/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 412/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 413/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 414/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 415/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 416/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 417/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 418/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 419/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 420/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 421/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 422/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 423/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0030
# Epoch 424/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0029
# Epoch 425/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 426/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 427/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 428/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 429/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 430/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 431/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 432/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 433/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 434/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 435/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 436/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 437/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 438/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 439/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 440/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 441/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 442/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 443/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 444/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 445/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 446/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 447/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 448/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 449/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 450/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 451/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0028
# Epoch 452/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 453/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 454/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 455/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 456/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 457/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0028
# Epoch 458/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 459/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 460/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 461/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 462/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 463/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 464/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 465/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 466/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 467/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 468/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 469/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 470/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 471/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 472/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 473/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 474/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 475/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 476/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 477/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 478/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 479/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 480/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 481/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 482/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 483/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 484/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 485/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0027
# Epoch 486/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 487/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 488/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 489/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0027
# Epoch 490/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 491/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 492/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 493/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 494/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 495/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 496/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 497/500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0026
# Epoch 498/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 499/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# Epoch 500/500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0026
# prediction error on pre-covid data
# **********************************
# [0.00252717]
# prediction error on post-covid data
# **********************************
# [0.00511439]
# Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted
# **********************************
# -0.0023202484
# 18/18 [==============================] - 0s 4ms/step
