# %% [markdown]
# # The effect of COVID-19 on deliveredKwh
# We designed three machine learning-based model (LSTM-based) that to predict the value of "dailyDeleivered".
#
# We monitored the prediction error of the pre and post COVID data to observe the effect of COVID-19 on the prediction error.
# We also observed the sign of the prediction error to see whether the predicted dailyDelivered values are greater or less than the actula values.
# The following code and results are for a dataset that contains data of residential premises.
#
# The prediction error for post-covid data is greater than the one for pre-covid data.

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from matplotlib.pyplot import locator_params
from numpy import genfromtxt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import normalize
from operator import add
import tensorflow as tf
#rom keras.backend import tensorflow_backend as K
import statsmodels
import statistics
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
def temporalize(arr,win_size,step_size,features,add_index=0):
  """
  arr: any 2D array whose columns are distinct variables and 
    rows are data records at some timestamp t
  win_size: size of data window (given in data points)
  step_size: size of window step (given in data point)
  
  Note that step_size is related to window overlap (overlap = win_size - step_size), in 
  case you think in overlaps."""
  #
  dataFrameTimeseries=pd.DataFrame()
  #
  w_list = list()
  n_records = arr.shape[0]
  remainder = (n_records - win_size) % step_size 
  num_windows = 1 + int((n_records - win_size - remainder) / step_size)
  for k in range(num_windows):
    w_list.append(arr[k*step_size:win_size-1+k*step_size+1])
    #
    #convert the matrix to data frame
    dataFrameTemp=pd.DataFrame(data=arr[k*step_size:win_size-1+k*step_size+1], columns=features)
    dataFrameTemp["timeseriesId"]=k+add_index
    dataFrameTimeseries=pd.concat([dataFrameTimeseries,dataFrameTemp])
    #
  return np.array(w_list),dataFrameTimeseries

# %%
def is_number(s):
        try:
            float(s)
            return True
        except ValueError:
            pass
        
        try:
            import unicodedata
            unicodedata.numeric(s)
            return True
        except (TypeError, ValueError):
            pass
        return False

# %%
def plot_(h_axis,v1_axis,v2_axis, title="Daily Delivered (kWh)"):
    plt.rcParams.update({'font.size': 15})
    plt.tight_layout()
    plt.figure(figsize=(30,3))
    plt.plot(h_axis, v1_axis, color="blue",marker="o", label="actual")
    plt.plot(h_axis,v2_axis, color="red",marker="o",label="predicted")
    plt.xticks(h_axis[0::31],rotation=90)
    plt.title(title)
    plt.show()

# %%
# split into train and test sets
def split_(dataset, train_size=0.67, dimension=2):
    train_size = int(len(dataset) * train_size)
    test_size = len(dataset) - train_size
    train=[]
    test=[]
    if dimension==1:
        train, test = dataset[0:train_size], dataset[train_size:len(dataset)]
    else:
        train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    return train,test

# %%
#Original LSTM
def lstm_(X,Y,n_features,excludedIndexes=[0,1],trainig_percentage=0.76):

    print(X.shape)
    print(Y.shape)
    model = Sequential()
    model.add(LSTM(100, activation=('tanh'), dropout=0.2, recurrent_dropout=0.2, stateful = False, input_shape = (win_size,n_features-len(excludedIndexes))))
    model.add(Dense(1))
    model.compile(loss=keras.losses.mean_squared_error, optimizer='rmsprop')
    model.summary()

    #Exclude indexes for analysis in training
    X_preprocessed=np.asarray(np.delete(X,excludedIndexes,axis=2)).astype(np.float32)
    #train on precovid data and test on all dataset
    Xtrain,Xtest=split_(X_preprocessed,trainig_percentage)
    Ytrain,Ytest=split_(Y,trainig_percentage,1)

    model.fit(Xtrain, Ytrain,epochs=100,verbose=1)
    #prediction error on pre-covid data (training data)
    yhat1 = model.predict(Xtrain, verbose=0)
    prediction_error1=np.square(Ytrain-yhat1).mean(axis=None).ravel()
    print("prediction error on pre-covid data")
    print("**********************************")
    print(prediction_error1)

    #prediction error on post-covid data (testing data)
    yhat2 = model.predict(Xtest, verbose=0)
    prediction_error2=np.square(Ytest-yhat2).mean(axis=None).ravel()
    print("prediction error on post-covid data")
    print("**********************************")
    print(prediction_error2)

    print("Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted")
    print("**********************************")
    print((Ytest-yhat2).mean(axis=None))

    #predict the entire data
    yhat=model.predict(X_preprocessed)

    h_axis=dataset["time"]
    v1_axis=dataset["dailyDelivered"]
    v2_axis=yhat.flatten()
    temp=np.zeros(win_size)
    v2_axis=np.concatenate([temp,v2_axis])
    plot_(h_axis,v1_axis,v2_axis)

# %%
def lstmAutoencoer(X,n_features,dailyDeliveredIndex=3,trainig_percentage=0.76):
    #LSTM-Autoencoder
    model = Sequential()
    model.add(LSTM(20,activation='tanh', input_shape=(win_size,n_features-2), return_sequences=False))
    model.add(RepeatVector(win_size))
    model.add(LSTM(20, activation='tanh', return_sequences=True))
    #2: excludes id and time from analysis
    model.add(TimeDistributed(Dense(n_features-2)))
    model.compile(optimizer='adam', loss="mse")
    model.summary()

    #remove id and time for trainig
    X_preprocessed=np.asarray(np.delete(X,[0,1],axis=2)).astype(np.float32)
    #train on precovid data and test on all dataset
    train,test=split_(X_preprocessed,trainig_percentage)

    model.fit(train, train, epochs=100, verbose=1)
    #prediction error on pre-covid data (training data)
    yhat1 = model.predict(train, verbose=0)
    prediction_error1=np.square(train-yhat1).mean(axis=None).ravel()
    print("prediction error on pre-covid data")
    print("**********************************")
    print(prediction_error1)

    #prediction error on post-covid data (testing data)
    yhat2 = model.predict(test, verbose=0)
    prediction_error2=np.square(test-yhat2).mean(axis=None).ravel()
    print("prediction error on post-covid data")
    print("**********************************")
    print(prediction_error2)

    print("Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted")
    print("**********************************")
    print((test-yhat2).mean(axis=None))

    #predict the entire data
    yhat = model.predict(X_preprocessed, verbose=1)
    #this structure is because overlap is win_size-1. Uncomment the commented lines for overlap=0
    #h_axis=np.array(dataFrameTimeseries["time"])
    h_axis=np.array(X)[:,0,1].flatten()
    #v1_axis=np.array(dataFrameTimeseries["residential-dailyDelivered"])
    v1_axis=np.array(X)[:,0,dailyDeliveredIndex].flatten()
    #v2_axis=np.array(yhat)[:,:,1].flatten()
    v2_axis=np.array(yhat)[:,0,1].flatten()
    plot_(h_axis,v1_axis,v2_axis)

# %%
#set window sizes and their overlap
win_size=10
overlap=win_size-1

#read data
dataset = pd.read_csv('datasets/pow_temp_isweekday.csv', engine='python')

#preprocess data
dataset=dataset.fillna(-1)
for column in dataset.columns:
    if is_number(dataset.iloc[1][column]) and column!="id":
        min_max=MinMaxScaler(feature_range=(0, 1))
        dataset[[column]]=min_max.fit_transform(dataset[[column]])

#set variables based on the data attributes
n_features=len(dataset.columns.values)
dailyDeliveredIndex=np.where(dataset.columns.values=="dailyDelivered")
dailyDeliveredIndex=dailyDeliveredIndex[0][0]
X,dataFrameTimeseries=temporalize(dataset.to_numpy(),win_size,win_size-overlap,dataset.columns.values)

# %%
#model1:
print("**********Model1: Original LSTM*******************************")
#remove id (index=0), time (index=1), and previous value of dailyDelivered for trainig
excludedIndexes=[0,1,dailyDeliveredIndex]
print(excludedIndexes)
lstm_(X[0:-1,:],dataset.to_numpy()[win_size:,dailyDeliveredIndex].astype(np.float32),n_features,excludedIndexes,trainig_percentage=0.76)

#model2:
print("**********Model2: Original LSTM*******************************")
#remove id and time for trainig
excludedIndexes=[0,1]
lstm_(X[0:-1,:],dataset.to_numpy()[win_size:,dailyDeliveredIndex].astype(np.float32),n_features,excludedIndexes,trainig_percentage=0.76)

#model3:
print("**********Model3: LSTM-Autoencoder*******************************")
lstmAutoencoer(X,n_features,dailyDeliveredIndex,trainig_percentage=0.76)
# Out:
# **********Model1: Original LSTM*******************************
# [0, 1, 3]
# (544, 10, 5)
# (544,)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100)               41200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 41,301
# Trainable params: 41,301
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1311
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0306
# Epoch 3/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0291
# Epoch 4/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0235
# Epoch 5/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0204
# Epoch 6/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0197
# Epoch 7/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0194
# Epoch 8/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0191
# Epoch 9/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0179
# Epoch 10/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0185
# Epoch 11/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0176
# Epoch 12/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0164
# Epoch 13/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0189
# Epoch 14/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0149
# Epoch 15/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0168
# Epoch 16/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0154
# Epoch 17/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0149
# Epoch 18/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0142
# Epoch 19/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0149
# Epoch 20/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0147
# Epoch 21/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0134
# Epoch 22/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0152
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0142
# Epoch 24/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0131
# Epoch 25/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0138
# Epoch 26/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0133
# Epoch 27/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0140
# Epoch 28/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0126
# Epoch 29/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0123
# Epoch 30/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0143
# Epoch 31/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0119
# Epoch 32/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0142
# Epoch 33/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0138
# Epoch 34/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 35/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0127
# Epoch 36/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0141
# Epoch 37/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0133
# Epoch 38/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0116
# Epoch 39/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0119
# Epoch 40/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0124
# Epoch 41/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0128
# Epoch 42/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0108
# Epoch 43/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0113
# Epoch 44/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0128
# Epoch 45/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0116
# Epoch 46/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0109
# Epoch 47/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0121
# Epoch 48/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 49/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0111
# Epoch 50/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0109
# Epoch 51/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0116
# Epoch 52/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0114
# Epoch 53/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0113
# Epoch 54/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0111
# Epoch 55/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0126
# Epoch 56/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 57/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0112
# Epoch 58/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0111
# Epoch 59/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0114
# Epoch 60/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0110
# Epoch 61/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0108
# Epoch 62/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104
# Epoch 63/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0110
# Epoch 64/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# Epoch 65/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0124
# Epoch 66/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0108
# Epoch 67/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0103
# Epoch 68/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0116
# Epoch 69/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 70/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0107
# Epoch 71/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104
# Epoch 72/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 73/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 74/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0094
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0107
# Epoch 76/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104
# Epoch 77/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0092
# Epoch 78/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 79/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0116
# Epoch 80/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0093
# Epoch 81/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 82/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0114
# Epoch 83/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 84/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097
# Epoch 85/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 86/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 87/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0103
# Epoch 88/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097
# Epoch 89/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 90/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0105
# Epoch 91/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 92/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0101
# Epoch 93/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0094
# Epoch 94/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0100
# Epoch 95/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097
# Epoch 96/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0100
# Epoch 97/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0107
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097
# Epoch 99/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 100/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0105
# prediction error on pre-covid data
# **********************************
# [0.01696733]
# prediction error on post-covid data
# **********************************
# [0.0332327]
# Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted
# **********************************
# -0.03601716
# **********Model2: Original LSTM*******************************
# (544, 10, 5)
# (544,)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100)               41600
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 41,701
# Trainable params: 41,701
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0776
# Epoch 2/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0172
# Epoch 3/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0171
# Epoch 4/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0156
# Epoch 5/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0137
# Epoch 6/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0151
# Epoch 7/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0129
# Epoch 8/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0123
# Epoch 9/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0112
# Epoch 10/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0138
# Epoch 11/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0111
# Epoch 12/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0135
# Epoch 13/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0104
# Epoch 14/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0118
# Epoch 15/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0118
# Epoch 16/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0108
# Epoch 17/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 18/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0119
# Epoch 19/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0103
# Epoch 20/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0097
# Epoch 21/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0091
# Epoch 22/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0115
# Epoch 23/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0100
# Epoch 24/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0095
# Epoch 25/100
# 13/13 [==============================] - ETA: 0s - loss: 0.010 - 0s 14ms/step - loss: 0.0102
# Epoch 26/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 27/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0106
# Epoch 28/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0086
# Epoch 29/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0100
# Epoch 30/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0090
# Epoch 31/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0102
# Epoch 32/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0091
# Epoch 33/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0095
# Epoch 34/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0097
# Epoch 35/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0093
# Epoch 36/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0093
# Epoch 37/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099
# Epoch 38/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 39/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 40/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0091
# Epoch 41/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0090
# Epoch 42/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0094
# Epoch 43/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0096
# Epoch 44/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082
# Epoch 45/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0085
# Epoch 46/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0098
# Epoch 47/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0085
# Epoch 48/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0088
# Epoch 49/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0092
# Epoch 50/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0088
# Epoch 51/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 52/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0094
# Epoch 53/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0088
# Epoch 54/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 55/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082
# Epoch 56/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0087
# Epoch 57/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0086
# Epoch 58/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 59/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082
# Epoch 60/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0078
# Epoch 61/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0079
# Epoch 62/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 63/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0084
# Epoch 64/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0084
# Epoch 65/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0079
# Epoch 66/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 67/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 68/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0081
# Epoch 69/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0075
# Epoch 70/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0083
# Epoch 71/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0087
# Epoch 72/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073
# Epoch 73/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0074
# Epoch 74/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0087
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 76/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0080
# Epoch 77/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0080
# Epoch 78/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078
# Epoch 79/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0079
# Epoch 80/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 81/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0075
# Epoch 82/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0083
# Epoch 83/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082
# Epoch 84/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0069
# Epoch 85/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0068
# Epoch 86/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 87/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0081
# Epoch 88/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0067
# Epoch 89/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 90/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073
# Epoch 91/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0079
# Epoch 92/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0073
# Epoch 93/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0076
# Epoch 94/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0077
# Epoch 95/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0071
# Epoch 96/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0085
# Epoch 97/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0069
# Epoch 98/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0079
# Epoch 99/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0075
# Epoch 100/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0078
# prediction error on pre-covid data
# **********************************
# [0.01816048]
# prediction error on post-covid data
# **********************************
# [0.0342013]
# Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted
# **********************************
# -0.019922165
# **********Model3: Original LSTM*******************************
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 20)                1920
# _________________________________________________________________
# repeat_vector (RepeatVector) (None, 10, 20)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 10, 20)            3280
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 3)             63
# =================================================================
# Total params: 5,263
# Trainable params: 5,263
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.3414
# Epoch 2/100
# 13/13 [==============================] - 0s 19ms/step - loss: 0.1899
# Epoch 3/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1247
# Epoch 4/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1134
# Epoch 5/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.1056
# Epoch 6/100
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0992
# Epoch 7/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0929
# Epoch 8/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0873
# Epoch 9/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0826
# Epoch 10/100
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0790
# Epoch 11/100
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0770
# Epoch 12/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0759
# Epoch 13/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0751
# Epoch 14/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0746
# Epoch 15/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0740
# Epoch 16/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0735
# Epoch 17/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0731
# Epoch 18/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0729
# Epoch 19/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0724
# Epoch 20/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0721
# Epoch 21/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0717
# Epoch 22/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0715
# Epoch 23/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0712
# Epoch 24/100
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0710
# Epoch 25/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0708
# Epoch 26/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0706
# Epoch 27/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0705
# Epoch 28/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0704
# Epoch 29/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0703
# Epoch 30/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0703
# Epoch 31/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0702
# Epoch 32/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0701
# Epoch 33/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0701
# Epoch 34/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0700
# Epoch 35/100
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0700
# Epoch 36/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0700
# Epoch 37/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0699
# Epoch 38/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0699
# Epoch 39/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0698
# Epoch 40/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0698
# Epoch 41/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0697
# Epoch 42/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0696
# Epoch 43/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0696
# Epoch 44/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0695
# Epoch 45/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0694
# Epoch 46/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0693
# Epoch 47/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0691
# Epoch 48/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0689
# Epoch 49/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0688
# Epoch 50/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0685
# Epoch 51/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0682
# Epoch 52/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0677
# Epoch 53/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0671
# Epoch 54/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0663
# Epoch 55/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0652
# Epoch 56/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0637
# Epoch 57/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0614
# Epoch 58/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0591
# Epoch 59/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0565
# Epoch 60/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0541
# Epoch 61/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0523
# Epoch 62/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0511
# Epoch 63/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0503
# Epoch 64/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0489
# Epoch 65/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0481
# Epoch 66/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0466
# Epoch 67/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0454
# Epoch 68/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0447
# Epoch 69/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0436
# Epoch 70/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0428
# Epoch 71/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0410
# Epoch 72/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0390
# Epoch 73/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0374
# Epoch 74/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0362
# Epoch 75/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0350
# Epoch 76/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0348
# Epoch 77/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0342
# Epoch 78/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0323
# Epoch 79/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0305
# Epoch 80/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0296
# Epoch 81/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0286
# Epoch 82/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0279
# Epoch 83/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0271
# Epoch 84/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0258
# Epoch 85/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0251
# Epoch 86/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0247
# Epoch 87/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0262
# Epoch 88/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0256
# Epoch 89/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0238
# Epoch 90/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0226
# Epoch 91/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0210
# Epoch 92/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0205
# Epoch 93/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0198
# Epoch 94/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0194
# Epoch 95/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0187
# Epoch 96/100
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0181
# Epoch 97/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0179
# Epoch 98/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0173
# Epoch 99/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0172
# Epoch 100/100
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0164
# prediction error on pre-covid data
# **********************************
# [0.01601712]
# prediction error on post-covid data
# **********************************
# [0.02054319]
# Error sign (actual-prediction) for post covid data: If Positive--> actual is greater than predicted
# **********************************
# 0.00062369107
# 18/18 [==============================] - 0s 4ms/step
